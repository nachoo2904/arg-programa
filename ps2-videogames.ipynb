# %%
import pandas as pd
df = pd.read_csv("C:/Users/dheth/Desktop/Cosas/playstation2_games.csv", sep = ",")

# %%
#Primeros 5 registros
df.head()
# Out:
#    Unnamed: 0                          Title      Developer  \
# 0           0  ¡Qué pasa Neng! El videojuego   Mere Mortals
# 1           1                .hack//frägment  CyberConnect2
# 2           2      .hack//G.U.vol.1//Rebirth  CyberConnect2
# 3           3    .hack//G.U.vol.2//Reminisce  CyberConnect2
# 4           4   .hack//G.U.vol.3//Redemption  CyberConnect2
#
#             Publisher First released          JP      EU/PAL          NA
# 0       Phoenix Games   2006-12-11EU  Unreleased    Released  Unreleased
# 1              Bandai   2005-11-23JP    Released  Unreleased  Unreleased
# 2              Bandai   2006-05-18JP    Released  Unreleased    Released
# 3  Namco Bandai Games   2006-09-28JP    Released  Unreleased    Released
# 4  Namco Bandai Games  2007-01-18 JP    Released  Unreleased    Released

# %%
#Ultimas 5 registros
df.tail()
# Out:
#       Unnamed: 0                                            Title  \
# 2028        2028                                  Kyojin no Hoshi
# 2029        2029  Kyoufu Shinbun (Heisei-Han) Kaiki! Shinrei File
# 2030        2030   Kyoushuu Kidou Butai: Kougeki Helicopter Senki
# 2031        2031                     Kyuuketsu Hime Yui: Senyasyo
# 2032        2032                         Kyuuketsu Kitan Moonties
#
#          Developer     Publisher First released        JP      EU/PAL  \
# 2028        Capcom        Capcom   2002-06-20JP  Released  Unreleased
# 2029        Konami        Konami   2003-08-07JP  Released  Unreleased
# 2030   ASK Co Ltd.         Taito   2004-09-30JP  Released  Unreleased
# 2031         GeneX         GeneX   2003-03-27JP  Released  Unreleased
# 2032  Interchannel  Interchannel   2008-02-28JP  Released  Unreleased
#
#               NA
# 2028  Unreleased
# 2029  Unreleased
# 2030  Unreleased
# 2031  Unreleased
# 2032  Unreleased

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2033 entries, 0 to 2032
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      2033 non-null   int64
#  1   Title           2033 non-null   object
#  2   Developer       2033 non-null   object
#  3   Publisher       2033 non-null   object
#  4   First released  2033 non-null   object
#  5   JP              2033 non-null   object
#  6   EU/PAL          2033 non-null   object
#  7   NA              2033 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 127.2+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Title', 'Developer', 'Publisher', 'First released', 'JP',
#        'EU/PAL', 'NA'],
#       dtype='object')

# %%
df.count()
# Out:
# Unnamed: 0        2033
# Title             2033
# Developer         2033
# Publisher         2033
# First released    2033
# JP                2033
# EU/PAL            2033
# NA                2033
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# Title             object
# Developer         object
# Publisher         object
# First released    object
# JP                object
# EU/PAL            object
# NA                object
# dtype: object

# %%
#Mostrar juegos desarrollados por Konami
df[df['Developer'] == 'Konami']
# Out:
#       Unnamed: 0                                            Title Developer  \
# 33            33                                   7 Blades Seven    Konami
# 55            55                    Adventure of Tokyo Disney Sea    Konami
# 62            62                              Aerobics Revolution    Konami
# 197          197          Ashita no Joe: Masshiro ni Moe Tsukiro!    Konami
# 267          267       The Baseball 2002: Battle Ball Park Sengen    Konami
# ...          ...                                              ...       ...
# 1901        1901                                    KeyboardMania    Konami
# 1902        1902              KeyboardMania II: 2nd Mix & 3rd Mix    Konami
# 1969        1969                  Kinniku Banzuke: Muscle Wars 21    Konami
# 2008        2008                  Korokke! Ban-Ou no Kiki o Sukue    Konami
# 2029        2029  Kyoufu Shinbun (Heisei-Han) Kaiki! Shinrei File    Konami
#
# ...

# %%
#Buscar si algún juego salio en Japón el dia de mi nacimiento
df[df['First released'] == '2004-04-29JP']
# Out:
#       Unnamed: 0                                             Title Developer  \
# 1284        1284  GetBackers Dakkanya: Urashinshiku Saikyou Battle    Konami
#
#      Publisher First released        JP      EU/PAL          NA
# 1284    Konami   2004-04-29JP  Released  Unreleased  Unreleased

# %%
#Buscar información de algún juego
df[df['Title'] == 'God of War']
# Out:
#       Unnamed: 0       Title            Developer  \
# 1318        1318  God of War  Santa Monica Studio
#
#                                            Publisher First released        JP  \
# 1318  Sony Computer EntertainmentKO,NA,PAL, CapcomJP   2005-03-22NA  Released
#
#         EU/PAL        NA
# 1318  Released  Released

# %%
#Mostrar los juegos de PS2 no lanzados para Japón
df[df['JP'] == 'Unreleased']
# Out:
#       Unnamed: 0                                              Title  \
# 0              0                      ¡Qué pasa Neng! El videojuego
# 14            14                            10 Pin: Champions Alley
# 23            23                                      21 Card Games
# 24            24                                       24: The Game
# 25            25                                         25 to Life
# ...          ...                                                ...
# 1994        1994            Konami Kids Playground: Alphabet Circus
# 1995        1995  Konami Kids Playground: Dinosaurs - Shapes & C...
# 1996        1996  Konami Kids Playground: Frogger Hop, Skip & Ju...
# 1997        1997  Konami Kids Playground: Toy Pals Fun with Numbers
# 2024        2024                                  Kya: Dark Lineage
#
#                  Developer             Publisher First released          JP  \
# ...

# %%
#Graficar y mostrar desarrolladora con más titulos
df['Developer'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: >
